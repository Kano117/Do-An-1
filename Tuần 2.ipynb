# %% [markdown]
# # Tuần 2(12/9-18/9)
#
# # Train model theo các video hướng dẫn trên Youtube
#
# ## **Thực hiện train model theo video *Real Time Sign Language Detection with Tensorflow Object Detection and Python | Deep Learning SSD* của *Nicholas Renotte***
#
# Link Youtube: [Real Time Sign Language Detection with Tensorflow Object Detection and Python | Deep Learning SSD](https://www.youtube.com/watch?v=pDXdlXlaCco)
#
# Link Github: [RealTimeObjectDetection](https://github.com/nicknochnack/RealTimeObjectDetection)
#
# - Cài đặt Jupyter Notebook theo link hướng dẫn: [Jupyter Notebook là gì](https://200lab.io/blog/jupyter-notebook-la-gi/)
#
#     Sau khi cài đặt Python version 3.12 và Jupyter Notebook, khởi chạy Jupyter Notebook theo hướng dẫn thì phát hiện máy không thể mở được [Localhost](http://Localhost) của Jupyter Notebook.
#
#     Khi sao chép link [Localhost](http://Localhost) của Jupyter Notebook từ Command Prompt và dán lên thanh tìm kiếm của chrome thì ra trang Localhost của Jupyter Notebook với nhiều folder và file lạ, không thể thực hiện giống với video, không thể upload folder vào.
#
#
# Sau khi khởi chạy Jupyter Notebook thất bại, chuyển sang video hướng dẫn khác.
#
# ## **Thực hiện train model theo danh sách video *Sign Language Detection Using YOLO v5 | Computer Vision* của *DSwithBappy***
#
# Link Youtube: [Sign Language Detection Using YOLO v5 | Computer Vision](https://www.youtube.com/playlist?list=PLkz_y24mlSJYWpwFbU8fyaBSwihoVHiJz)
#
# Link Github: [Sign-Language-Generation-From-Video-using-YOLOV5](https://github.com/entbappy/Sign-Language-Generation-From-Video-using-YOLOV5)
#
# Thực hiện mở file *Sign_language_Generation_Using_YOLO_v5.ipynb* trong Github lên Google Colab để thực hiện việc train model nhận diện. Link Google Colab: [Google Collab](https://colab.research.google.com/drive/1O364FjeYc3cX-fnNwXgIPBFuY-gwUmf5?authuser=1)
#
# Sau khi thực hiện theo video hướng dẫn thì trong quá trình thực hiện gặp phải lỗi ở phần dưới đây:
#
# **%cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/MyDrive/Research/SignLanguageDetection/model**
#
# Sau khi khởi chạy thì chương trình thông báo lỗi không tìm thấy *Research/SignLanguageDetection/model* trong Google Drive. Sau khi phát hiện lỗi thì thêm folder Research/SignLanguageDetection/model vào Google Drive và chạy lại đoạn code trên. Sau khi chạy lại thì em thu được model [best.pt](http://best.pt) ở folder model trong folder SignLanguageDetection.
#
# Chạy wecam nhận diện theo video hướng dẫn, khi xem video thì phát hiện còn thiếu cài đặt Anaconda. Thực hiện cài đặt Anaconda vào máy. Ngoài ra Github trong video có thêm folder yolov5 mà khi em nhấn vào đường dẫn Github thì không có nó. Em tải thêm folder yolov5 từ Github(link Github: https://github.com/ultralytics/yolov5 )vào folder Sign-Language-Generation-From-Video-using-YOLOV5. Sau khi khởi chạy file [*run.py*](http://run.py) theo hướng dẫn của video thì chương trình thông báo lỗi sau đây:
#
# **Loi@DESKTOP-9V0PM3A MINGW64 ~/Documents/TestCV/Sign-Language-Generation-From-Video-using-YOLOV5/yolov5 (master)
# $ python [run.py](http://run.py/)
# detect: weights=['[best.pt](http://best.pt/)'], source=0, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-366-gf7322921 Python-3.9.19 torch-2.4.1+cpu CPU**
#
# **Traceback (most recent call last):
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\[detect.py](http://detect.py/)", line 437, in <module>
# main(opt)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\[detect.py](http://detect.py/)", line 432, in main
# run(**vars(opt))
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\torch\utils\_contextlib.py", line 116, in decorate_context
# return func(*args, **kwargs)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\[detect.py](http://detect.py/)", line 166, in run
# model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\models\[common.py](http://common.py/)", line 489, in init
# model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)**
#
# **File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\models\[experimental.py](http://experimental.py/)", line 98, in attempt_load
# ckpt = torch.load(attempt_download(w), map_location="cpu")  # load
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\ultralytics\utils\[patches.py](http://patches.py/)", line 86, in torch_load
# return _torch_load(*args, **kwargs)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\torch\[serialization.py](http://serialization.py/)", line 1097, in load
# return _load(
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\torch\[serialization.py](http://serialization.py/)", line 1525, in _load
# result = unpickler.load()
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\[pathlib.py](http://pathlib.py/)", line 1084, in new
# raise NotImplementedError("cannot instantiate %r on your system"
# NotImplementedError: cannot instantiate 'PosixPath' on your system
# (C:\Users\Loi\Documents11:16:38estCV\Sign-Language-Generation-From-Video-using-YOLOV5v)
# Loi@DESKTOP-9V0PM3A MINGW64 ~/Documents/TestCV/Sign-Language-Generation-From-Video-using-YOLOV5/yolov5 (master)
# $ python [run.py](http://run.py/)
# detect: weights=['[best.pt](http://best.pt/)'], source=0, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-366-gf7322921 Python-3.9.19 torch-2.4.1+cpu CPU**
#
# **Traceback (most recent call last):
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\[detect.py](http://detect.py/)", line 437, in <module>
# main(opt)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\[detect.py](http://detect.py/)", line 432, in main
# run(**vars(opt))
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\torch\utils\_contextlib.py", line 116, in decorate_context
# return func(*args, **kwargs)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\[detect.py](http://detect.py/)", line 166, in run
# model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\models\[common.py](http://common.py/)", line 489, in init
# model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)**
#
# **File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\yolov5\models\[experimental.py](http://experimental.py/)", line 98, in attempt_load
# ckpt = torch.load(attempt_download(w), map_location="cpu")  # load
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\ultralytics\utils\[patches.py](http://patches.py/)", line 86, in torch_load
# return _torch_load(*args, **kwargs)
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\torch\[serialization.py](http://serialization.py/)", line 1097, in load
# return _load(
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\site-packages\torch\[serialization.py](http://serialization.py/)", line 1525, in _load
# result = unpickler.load()
# File "C:\Users\Loi\Documents\TestCV\Sign-Language-Generation-From-Video-using-YOLOV5\env\lib\[pathlib.py](http://pathlib.py/)", line 1084, in new
# raise NotImplementedError("cannot instantiate %r on your system"
# NotImplementedError: cannot instantiate 'PosixPath' on your system**
# <br>Lỗi gặp phải xuất phát từ việc không thể khởi tạo `PosixPath` trên hệ thống Windows. Điều này xảy ra do code đang cố sử dụng `PosixPath` (dành cho hệ điều hành Unix) trong khi đang sử dụng hệ điều hành Windows, vốn dùng `WindowsPath`.
#
# ## **Thực hiện train model theo video *Chapter 50: Yolov8 for custom dataset ASL Sign Language WhatsApp +91-8909603708 for Research Project* của *[Code with Kristi](https://www.youtube.com/@codewithkristi)***
#
# [Link Youtube: https://www.youtube.com/watch?v=FU1nqyhklM8](https://www.notion.so/Link-Youtube-https-www-youtube-com-watch-v-FU1nqyhklM8-10d92668930c80e4ac32f6d233c1dfef?pvs=21)
#
# [Link Github: https://github.com/sachin365123/Yolov8-for-custom-dataset-ASL-Sign-Language](https://www.notion.so/Link-Github-https-github-com-sachin365123-Yolov8-for-custom-dataset-ASL-Sign-Language-10d92668930c8020a974f1c5187ac1e4?pvs=21)
#
# Thực hiện mở file *Yolov8_ASL_Sign_Language.ipynb* trong Github lên Google Colab để thực hiện việc train model nhận diện.
#
# Sau khi thực hiện theo video hướng dẫn thì trong quá trình thực hiện gặp phải lỗi ở phần dưới đây:
#
# **!mkdir /content/Yolov8SignLanguage-3/datasets
# %cd /content/Yolov8SignLanguage-3/datasets
#
# from roboflow import Roboflow
# rf = Roboflow(api_key="U9X00mIoCIlSYdyte6NZ")
# project = rf.workspace("invertis").project("yolov8signlanguage")
# dataset = project.version(3).download("yolov8")**
#
# Em gặp phải lỗi api_key của dataset Roboflow nên em tìm nguồn dataset khác ở Roboflow để thay thế. Nguồn dataset American Sign Language tìm được là ***American Sign Language Letters Computer Vision Project*** của ***David Lee,*** Link Roboflow: ****https://universe.roboflow.com/david-lee-d0rhs/american-sign-language-letters.
#
# Sau khi cài đặt dataset để train model từ nguồn Roboflow thì em lại gặp tiếp lỗi ở phần code dưới đây:
#
# **!yolo task=detect mode=train model=/content/yolov8s.pt data=/content/American-Sign-Language-Letters-6/data.yaml epochs=30 imgsz=640**
#
# ***FileNotFoundError:
# Dataset '/content/American-Sign-Language-Letters-6/data.yaml' images not found ⚠️, missing path '/content/American-Sign-Language-Letters-6/American-Sign-Language-Letters-6/valid/images'
# Note dataset download directory is '/content/datasets'. You can update this in '/root/.config/Ultralytics/settings.yaml'***
#
# Sau khi không tìm được cách xử lý lỗi trên thì em lại tìm video khác.
#
# ## **Thực hiện train model theo video *Train YOLOv8 on Custom Dataset | Sign Language Alphabets Detection and Recognition using YOLOv8* của *[Muhammad Moin](https://www.youtube.com/@muhammadmoinfaisal)***
#
# [Link Youtube: https://www.youtube.com/watch?v=-UoSr9Z_Bg0](https://www.notion.so/Link-Youtube-https-www-youtube-com-watch-v-UoSr9Z_Bg0-10d92668930c808a89a3e857ca68d8b0?pvs=21)
#
# [Link Github: https://github.com/MuhammadMoinFaisal/Sign-Language-Alphabets-Detection-and-Recongition-using-YOLOv8](https://www.notion.so/Link-Github-https-github-com-MuhammadMoinFaisal-Sign-Language-Alphabets-Detection-and-Recongition-10d92668930c80879ab0d37e5eb6320d?pvs=21)
#
# Thực hiện mở file *Sign_Language_Alphabets_Detection_and_Recognition_using_YOLOv8.ipynb* trong Github lên Google Colab để thực hiện việc train model nhận diện. Link Google Colab: https://colab.research.google.com/drive/1iwUa4TdjQTMgU8gRdNxMtx_qYEXAnfs6?authuser=1#scrollTo=SA3S___qj88u
#
# Sau khi thực hiện theo video hướng dẫn thì trong quá trình thực hiện lại gặp phải lỗi ở phần dưới đây:
#
# **%cd {HOME}**
#
# **!yolo task=detect mode=train [model=yolov8l.pt](http://model=yolov8l.pt/) data={dataset.location}/data.yaml epochs=50 imgsz=800**
#
# ***FileNotFoundError:
# Dataset '/content/American-Sign-Language-Letters-6/data.yaml' images not found ⚠️, missing path '/content/American-Sign-Language-Letters-6/American-Sign-Language-Letters-6/valid/images'
# Note dataset download directory is '/content/datasets'. You can update this in '/root/.config/Ultralytics/settings.yaml'***
#
# Sau khi không tìm được cách xử lý lỗi trên thì em lại tìm video khác.
#
# ## **Thực hiện train model theo video *Real Time Sign Language Detection with YOLO-NAS and Webcam : Step by Step Tutorial | Custom Dataset* của *[Muhammad Moin](https://www.youtube.com/@muhammadmoinfaisal)***
#
# Link Youtube: [Real Time Sign Language Detection with YOLO-NAS and Webcam : Step by Step Tutorial | Custom Dataset](https://www.youtube.com/watch?v=1FOawpuQflg)
#
# Link Github: [YOLO-NAS Sign Language Detection](https://github.com/MuhammadMoinFaisal/Computervisionprojects/tree/main/YOLO-NAS%20Sign%20Language%20Detection)
#
# Thực hiện mở file *Train_YOLONAS_Custom_Dataset_Sign_Language_Complete.ipynb* trong Github lên Google Colab để thực hiện việc train model nhận diện. Link Google Colab: https://colab.research.google.com/drive/1vP6rsiizdUzHYrmFKvwBPdxy35Dyh1NX?authuser=1#scrollTo=63PxbjJi_4jr
#
# Sau khi thực hiện theo video hướng dẫn thì trong quá trình thực hiện lại gặp phải lỗi ở phần dưới đây:
#
# **from super_gradients.training import Trainer
# from super_gradients.training import dataloaders
# from super_gradients.training.dataloaders.dataloaders import coco_detection_yolo_format_train, coco_detection_yolo_format_val**
#
# ***--------------------------------------------------------------------------***
#
# ***ModuleNotFoundError                       Traceback (most recent call last)***
#
# ***<ipython-input-2-0200189a802d> in <cell line: 1>()***
#
# ***---> 1 from super_gradients.training import Trainer***
#
#   ***2 from super_gradients.training import dataloaders***
#
#   ***3 from super_gradients.training.dataloaders.dataloaders import coco_detection_yolo_format_train, coco_detection_yolo_format_val***
#
# ***ModuleNotFoundError: No module named 'super_gradients'***
#
# ***--------------------------------------------------------------------------***
#
# ***NOTE: If your import is failing due to a missing package, you can***
#
# ***manually install dependencies using either !pip or !apt.***
#
# ***To view examples of installing some common dependencies, click the***
#
# ***"Open Examples" button below.***
#
# ***--------------------------------------------------------------------------***
#
# Sau khi không tìm được cách xử lý lỗi trên thì em lại tìm video khác.
#
# ## **Thực hiện train model theo video *Fire Detection YOLOv8 with Python (real time & custom data)* của *[University of The Future](https://www.youtube.com/@universityofthefuture2077)***
#
# Link Youtube: [Fire Detection YOLOv8 with Python (real time & custom data)](https://www.youtube.com/watch?v=-RDeVPHipZU)
#
# Link Github: [yolov8-on-fire-colab](https://github.com/mcdominik/machine_learning/tree/master/yolov8-on-fire-colab)
#
# Thực hiện mở file *yolo8_on_fire.ipynb* trong Github lên Google Colab để thực hiện việc train model nhận diện. Link Google Colab: https://colab.research.google.com/drive/1wW4-CirEYCxmfMrAdO7NHduNbA-56Ru0?authuser=1
#
# Sau khi thực hiện theo video hướng dẫn thì trong quá trình thực hiện lại gặp phải lỗi ở phần dưới đây:
#
# **!yolo task=detect mode=train model=yolov8s.pt data=/content/American-Sign-Language-Letters-6/data.yaml epochs=10 imgsz=640**
#
# ***FileNotFoundError:
# Dataset '/content/American-Sign-Language-Letters-6/data.yaml' images not found ⚠️, missing path '/content/American-Sign-Language-Letters-6/American-Sign-Language-Letters-6/valid/images'
# Note dataset download directory is '/content/datasets'. You can update this in '/root/.config/Ultralytics/settings.yaml'***
#
# Sau đó thì em thử thay dataset khác từ Roboflow là ***sign language Computer Vision Project*** của ***Roboflow 100***. Dù vậy sau khi thay vẫn gặp lỗi tương tự là
#
# ***FileNotFoundError:***
#
# ***Dataset '/content/Sign-Language-2/data.yaml' images not found ⚠️, missing path '/content/Sign-Language-2/Sign-Language-2/valid/images'
# Note dataset download directory is '/content/datasets'. You can update this in '/root/.config/Ultralytics/settings.yaml'***
#
# Sau một thời gian thì em đã tìm ra lỗi nằm ở đâu sau khi thêm /content vào hai dòng train và val của data.yaml thì đã chạy train thành công. Sau khi train xong cỡ 10 phút thì thu được model best.pt rồi làm tiếp theo video hướng dẫn. Theo hướng dẫn, em tạo thêm file run.py trên Visual Studio để chạy wecam thì khởi chạy thành công.
